# %% [markdown]
# 1. Print kalimat di phyton

# %%
print("Nama: Nur Insyirah")
print("NIM: 240210502026")
# Out:
# Nama: Nur Insyirah
# NIM: 240210502026

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# 2. Menjorok ke dalam sebagai penanda blok kode program/kurung kurawal {}, spasi isinya harus sejajar

# %%
if 5 > 2:
  print("Lima lebih besar daripada dua")
# Out:
# Lima lebih besar daripada dua

# %%
if True:
    print("benar")
else:
    print("salah")
# Out:
# benar

# %% [markdown]
# 3. penggunaan ; opsional, digunakan untuk memisahkan beberapa pernyataan yang ditulis dalam satu baris

# %%
print("Halo"); print("Apa kabar?"); print("Sampai jumpa!")
# Out:
# Halo
# Apa kabar?
# Sampai jumpa!

# %% [markdown]
# 4. print angka

# %%
print(50000)
print(3 + 3)
# Out:
# 50000
# 6

# %% [markdown]
# ## analisis

# %% [markdown]
# ## Python Operators

# %% [markdown]
# #### Arithmetic Operators
